# %%
# %pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install numpy scipy pandas matplotlib seaborn requests
# Out:
# ...
#   Using cached numpy-1.26.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 565.8 kB/s eta 0:00:00 kB/s eta 0:00:01
# ...
#   Using cached pandas-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# ...
#   Using cached matplotlib-3.8.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# ...
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached tzdata-2023.4-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached contourpy-1.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.47.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (157 kB)
# ...
#   Using cached kiwisolver-1.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# ...

# %%
import requests # http requests, web scraping, apis
import os

r = requests.get("https://github.com/adambard/learnxinyminutes-docs")
r.status_code
# r.text # raw source
# print(r.text) # print formatted

os.getcwd() # get current working directory

# write a file
with open("learnxinminutes.html", "wb") as f:
    f.write(r.text.encode("UTF-8"))

# %%
# downloading a csv
file_path = "https://datahub.io/core/s-and-p-500-companies/r/"
file_name = "constituents.csv"
r = requests.get(file_path + file_name)
print(r.text)
with open(file_name, "wb") as f:
    f.write(r.text.encode("UTF-8"))
# Out:
# Symbol,Name,Sector
# MMM,3M,Industrials
# AOS,A. O. Smith,Industrials
# ABT,Abbott Laboratories,Health Care
# ABBV,AbbVie,Health Care
# ABMD,Abiomed,Health Care
# ACN,Accenture,Information Technology
# ATVI,Activision Blizzard,Communication Services
# ADM,ADM,Consumer Staples
# ADBE,Adobe,Information Technology
# AAP,Advance Auto Parts,Consumer Discretionary
# AMD,Advanced Micro Devices,Information Technology
# AES,AES Corp,Utilities
# AFL,Aflac,Financials
# A,Agilent Technologies,Health Care
# APD,Air Products & Chemicals,Materials
# AKAM,Akamai Technologies,Information Technology
# ALK,Alaska Air Group,Industrials
# ALB,Albemarle Corporation,Materials
# ARE,Alexandria Real Estate Equities,Real Estate
# ALGN,Align Technology,Health Care
# ALLE,Allegion,Industrials
# LNT,Alliant Energy,Utilities
# ALL,Allstate Corp,Financials
# GOOGL,Alphabet (Class A),Communication Services
# GOOG,Alphabet (Class C),Communication Services
# MO,Altria Group,Consumer Staples
# ...
